# %% [markdown]
# Last updated: April 12 2024
#
# # 👋 PyCaret Multiclass Classification Tutorial
#
# PyCaret is an open-source, low-code machine learning library in Python that automates machine learning workflows. It is an end-to-end machine learning and model management tool that exponentially speeds up the experiment cycle and makes you more productive.
#
# Compared with the other open-source machine learning libraries, PyCaret is an alternate low-code library that can be used to replace hundreds of lines of code with a few lines only. This makes experiments exponentially fast and efficient. PyCaret is essentially a Python wrapper around several machine learning libraries and frameworks, such as scikit-learn, XGBoost, LightGBM, CatBoost, spaCy, Optuna, Hyperopt, Ray, and a few more.
#
# The design and simplicity of PyCaret are inspired by the emerging role of citizen data scientists, a term first used by Gartner. Citizen Data Scientists are power users who can perform both simple and moderately sophisticated analytical tasks that would previously have required more technical expertise.

# %% [markdown]
# # 💻 Installation
#
# PyCaret is tested and supported on the following 64-bit systems:
# - Python 3.7 – 3.10
# - Python 3.9 for Ubuntu only
# - Ubuntu 16.04 or later
# - Windows 7 or later
#
# You can install PyCaret with Python's pip package manager:
#
# `pip install pycaret`
#
# PyCaret's default installation will not install all the extra dependencies automatically. For that you will have to install the full version:
#
# `pip install pycaret[full]`
#
# or depending on your use-case you may install one of the following variant:
#
# - `pip install pycaret[analysis]`
# - `pip install pycaret[models]`
# - `pip install pycaret[tuner]`
# - `pip install pycaret[mlops]`
# - `pip install pycaret[parallel]`
# - `pip install pycaret[test]`

# %%
# check installed version
# !pip install joblib==1.3.0
# !pip install pycaret==3.3.0
#!pip install pycaret --upgrade
import pycaret
pycaret.__version__
# Out:
# Collecting joblib==1.3.0
#   Downloading joblib-1.3.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.9/301.9 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.0
#     Uninstalling joblib-1.4.0:
#       Successfully uninstalled joblib-1.4.0
# Successfully installed joblib-1.3.0
# Collecting pycaret==3.3.0
#   Downloading pycaret-3.3.0-py3-none-any.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (4.66.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (1.25.2)
# Requirement already satisfied: pandas<2.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (2.0.3)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (3.1.3)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (1.3.0)
# Collecting scikit-learn>1.4.0 (from pycaret==3.3.0)
#   Downloading scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 25.0 MB/s eta 0:00:00
# Collecting pyod>=1.1.3 (from pycaret==3.3.0)
#   Downloading pyod-1.1.3.tar.gz (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting imbalanced-learn>=0.12.0 (from pycaret==3.3.0)
#   Downloading imbalanced_learn-0.12.2-py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 19.6 MB/s eta 0:00:00
# Collecting category-encoders>=2.4.0 (from pycaret==3.3.0)
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (4.1.0)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (0.58.1)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (5.9.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (7.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (5.10.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (2.2.1)
# Collecting deprecation>=2.1.0 (from pycaret==3.3.0)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting xxhash (from pycaret==3.3.0)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<3.8.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (3.7.1)
# Collecting scikit-plot>=0.3.7 (from pycaret==3.3.0)
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (5.15.0)
# Collecting kaleido>=0.2.1 (from pycaret==3.3.0)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.1 MB/s eta 0:00:00
# Collecting schemdraw==0.15 (from pycaret==3.3.0)
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.7 MB/s eta 0:00:00
# Collecting plotly-resampler>=0.8.3.1 (from pycaret==3.3.0)
#   Downloading plotly_resampler-0.10.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.3.0) (0.14.1)
# Collecting sktime>=0.26.0 (from pycaret==3.3.0)
#   Downloading sktime-0.28.0-py3-none-any.whl (21.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 28.8 MB/s eta 0:00:00
# Collecting tbats>=1.1.3 (from pycaret==3.3.0)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.8 MB/s eta 0:00:00
# Collecting pmdarima>=2.0.4 (from pycaret==3.3.0)
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.6 MB/s eta 0:00:00
# Collecting wurlitzer (from pycaret==3.3.0)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders>=2.4.0->pycaret==3.3.0) (0.5.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation>=2.1.0->pycaret==3.3.0) (24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn>=0.12.0->pycaret==3.3.0) (3.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.12.0->pycaret==3.3.0) (3.18.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.5.0->pycaret==3.3.0)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.3.0) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.3.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.3.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.3.0) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.3.0) (3.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8.0->pycaret==3.3.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8.0->pycaret==3.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8.0->pycaret==3.3.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8.0->pycaret==3.3.0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8.0->pycaret==3.3.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8.0->pycaret==3.3.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8.0->pycaret==3.3.0) (2.8.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.3.0) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.3.0) (4.19.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.3.0) (5.7.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.0->pycaret==3.3.0) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->pycaret==3.3.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0->pycaret==3.3.0) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.14.0->pycaret==3.3.0) (8.2.3)
# Collecting dash>=2.9.0 (from plotly-resampler>=0.8.3.1->pycaret==3.3.0)
#   Downloading dash-2.16.1-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 68.5 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.8.0 (from plotly-resampler>=0.8.3.1->pycaret==3.3.0)
#   Downloading orjson-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 6.9 MB/s eta 0:00:00
# Collecting tsdownsample>=0.1.3 (from plotly-resampler>=0.8.3.1->pycaret==3.3.0)
#   Downloading tsdownsample-0.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 71.2 MB/s eta 0:00:00
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima>=2.0.4->pycaret==3.3.0) (3.0.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima>=2.0.4->pycaret==3.3.0) (2.0.7)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod>=1.1.3->pycaret==3.3.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.3.0) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.3.0) (2024.2.2)
# Collecting scikit-base<0.8.0 (from sktime>=0.26.0->pycaret==3.3.0)
#   Downloading scikit_base-0.7.6-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0) (3.0.2)
# Collecting dash-html-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0) (4.11.0)
# Collecting retrying (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0) (1.6.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.3.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.3.0) (6.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.3.0) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.0) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.0) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret==3.3.0) (4.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret==3.3.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret==3.3.0) (0.2.13)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (6.5.5)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret==3.3.0) (8.1.7)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.0.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.3.0) (2.22)
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.1.3-py3-none-any.whl size=190250 sha256=21e1e8297d670d4714b0a6bc45c656e07a7f93a93f7fb851a57705ad328d849a
#   Stored in directory: /root/.cache/pip/wheels/05/f8/db/124d43bec122d6ec0ab3713fadfe25ebed8af52ec561682b4e
# Successfully built pyod
# Installing collected packages: kaleido, dash-table, dash-html-components, dash-core-components, xxhash, wurlitzer, tsdownsample, scikit-base, schemdraw, retrying, orjson, jedi, deprecation, scikit-learn, sktime, scikit-plot, pyod, imbalanced-learn, dash, pmdarima, plotly-resampler, category-encoders, tbats, pycaret
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed category-encoders-2.6.3 dash-2.16.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecation-2.1.0 imbalanced-learn-0.12.2 jedi-0.19.1 kaleido-0.2.1 orjson-3.10.1 plotly-resampler-0.10.0 pmdarima-2.0.4 pycaret-3.3.0 pyod-1.1.3 retrying-1.3.4 schemdraw-0.15 scikit-base-0.7.6 scikit-learn-1.4.2 scikit-plot-0.3.7 sktime-0.28.0 tbats-1.1.3 tsdownsample-0.1.3 wurlitzer-3.0.3 xxhash-3.4.1
# '3.3.0'

# %% [markdown]
# # 🚀 Quick start

# %% [markdown]
# PyCaret’s Classification Module is a supervised machine learning module that is used for classifying elements into groups. The goal is to predict the categorical class labels which are discrete and unordered.
#
# Some common use cases include predicting customer default (Yes or No), predicting customer churn (customer will leave or stay), the disease found (positive or negative).
#
# This module can be used for binary or multiclass problems. It provides several pre-processing features that prepare the data for modeling through the setup function. It has over 18 ready-to-use algorithms and several plots to analyze the performance of trained models.
#
# A typical workflow in PyCaret consist of following 5 steps in this order:
#
# ## **Setup** ➡️ **Compare Models** ➡️ **Analyze Model** ➡️ **Prediction** ➡️ **Save Model**

# %%
# loading sample dataset from pycaret dataset module
from pycaret.datasets import get_data
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Setup
# This function initializes the training environment and creates the transformation pipeline. Setup function must be called before executing any other function in PyCaret. It only has two required parameters i.e. `data` and `target`. All the other parameters are optional.

# %%
# import pycaret classification and init setup
from pycaret.classification import *
s = setup(data, target = 'species', session_id = 123)
# Out:
# <style type="text/css">
# #T_2d074_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2d074" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d074_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2d074_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d074_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d074_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2d074_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d074_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2d074_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d074_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2d074_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d074_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_2d074_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d074_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_2d074_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2d074_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_2d074_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2d074_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_2d074_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2d074_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_2d074_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2d074_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_2d074_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2d074_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_2d074_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2d074_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_2d074_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2d074_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_2d074_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2d074_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_2d074_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2d074_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_2d074_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2d074_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_2d074_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2d074_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_2d074_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2d074_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_2d074_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2d074_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_2d074_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2d074_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_2d074_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2d074_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2d074_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_2d074_row19_col1" class="data row19 col1" >3434</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Once the setup has been successfully executed it shows the information grid containing experiment level information.
#
# - **Session id:**  A pseudo-random number distributed as a seed in all functions for later reproducibility. If no `session_id` is passed, a random number is automatically generated that is distributed to all functions.<br/>
# <br/>
# - **Target type:**  Binary, Multiclass, or Regression. The Target type is automatically detected. <br/>
# <br/>
# - **Label Encoding:**  When the Target variable is of type string (i.e. 'Yes' or 'No') instead of 1 or 0, it automatically encodes the label into 1 and 0 and displays the mapping (0 : No, 1 : Yes) for reference. In this tutorial, no label encoding is required since the target variable is of numeric type. <br/>
# <br/>
# - **Original data shape:**  Shape of the original data prior to any transformations. <br/>
# <br/>
# - **Transformed train set shape :**  Shape of transformed train set <br/>
# <br/>
# - **Transformed test set shape :**  Shape of transformed test set <br/>
# <br/>
# - **Numeric features :**  The number of features considered as numerical. <br/>
# <br/>
# - **Categorical features :**  The number of features considered as categorical. <br/>

# %% [markdown]
# PyCaret has two set of API's that you can work with. (1) Functional (as seen above) and (2) Object Oriented API.
#
# With Object Oriented API instead of executing functions directly you will import a class and execute methods of class.

# %%
# import ClassificationExperiment and init the class
from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()

# %%
# check the type of exp
type(exp)
# Out:
# pycaret.classification.oop.ClassificationExperiment

# %%
# init setup on exp
exp.setup(data, target = 'species', session_id = 123)
# Out:
# <style type="text/css">
# #T_cbd90_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cbd90" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbd90_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cbd90_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbd90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbd90_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cbd90_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cbd90_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cbd90_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cbd90_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cbd90_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cbd90_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_cbd90_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cbd90_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_cbd90_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cbd90_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_cbd90_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cbd90_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_cbd90_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cbd90_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_cbd90_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cbd90_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_cbd90_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cbd90_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_cbd90_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cbd90_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_cbd90_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cbd90_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_cbd90_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cbd90_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_cbd90_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cbd90_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_cbd90_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cbd90_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_cbd90_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cbd90_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_cbd90_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cbd90_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_cbd90_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cbd90_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_cbd90_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cbd90_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_cbd90_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cbd90_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cbd90_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_cbd90_row19_col1" class="data row19 col1" >3066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You can use any of the two method i.e. Functional or OOP and even switch back and forth between two set of API's. The choice of method will not impact the results and has been tested for consistency.

# %% [markdown]
# ## Compare Models
#
# This function trains and evaluates the performance of all the estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores. Metrics evaluated during CV can be accessed using the `get_metrics` function. Custom metrics can be added or removed using `add_metric` and `remove_metric` function.

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_5c615 th {
#   text-align: left;
# }
# #T_5c615_row0_col0, #T_5c615_row1_col0, #T_5c615_row2_col0, #T_5c615_row3_col0, #T_5c615_row4_col0, #T_5c615_row4_col1, #T_5c615_row4_col3, #T_5c615_row4_col4, #T_5c615_row4_col5, #T_5c615_row4_col6, #T_5c615_row4_col7, #T_5c615_row5_col0, #T_5c615_row5_col1, #T_5c615_row5_col3, #T_5c615_row5_col4, #T_5c615_row5_col5, #T_5c615_row5_col6, #T_5c615_row5_col7, #T_5c615_row6_col0, #T_5c615_row6_col1, #T_5c615_row6_col3, #T_5c615_row6_col4, #T_5c615_row6_col5, #T_5c615_row6_col6, #T_5c615_row6_col7, #T_5c615_row7_col0, #T_5c615_row7_col1, #T_5c615_row7_col3, #T_5c615_row7_col4, #T_5c615_row7_col5, #T_5c615_row7_col6, #T_5c615_row7_col7, #T_5c615_row8_col0, #T_5c615_row8_col1, #T_5c615_row8_col3, #T_5c615_row8_col4, #T_5c615_row8_col5, #T_5c615_row8_col6, #T_5c615_row8_col7, #T_5c615_row9_col0, #T_5c615_row9_col1, #T_5c615_row9_col3, #T_5c615_row9_col4, #T_5c615_row9_col5, #T_5c615_row9_col6, #T_5c615_row9_col7, #T_5c615_row10_col0, #T_5c615_row10_col1, #T_5c615_row10_col3, #T_5c615_row10_col4, #T_5c615_row10_col5, #T_5c615_row10_col6, #T_5c615_row10_col7, #T_5c615_row11_col0, #T_5c615_row11_col1, #T_5c615_row11_col3, #T_5c615_row11_col4, #T_5c615_row11_col5, #T_5c615_row11_col6, #T_5c615_row11_col7, #T_5c615_row12_col0, #T_5c615_row12_col1, #T_5c615_row12_col3, #T_5c615_row12_col4, #T_5c615_row12_col5, #T_5c615_row12_col6, #T_5c615_row12_col7, #T_5c615_row13_col0, #T_5c615_row13_col1, #T_5c615_row13_col3, #T_5c615_row13_col4, #T_5c615_row13_col5, #T_5c615_row13_col6, #T_5c615_row13_col7, #T_5c615_row14_col0, #T_5c615_row14_col1, #T_5c615_row14_col3, #T_5c615_row14_col4, #T_5c615_row14_col5, #T_5c615_row14_col6, #T_5c615_row14_col7 {
#   text-align: left;
# }
# #T_5c615_row0_col1, #T_5c615_row0_col2, #T_5c615_row0_col3, #T_5c615_row0_col4, #T_5c615_row0_col5, #T_5c615_row0_col6, #T_5c615_row0_col7, #T_5c615_row1_col1, #T_5c615_row1_col2, #T_5c615_row1_col3, #T_5c615_row1_col4, #T_5c615_row1_col5, #T_5c615_row1_col6, #T_5c615_row1_col7, #T_5c615_row2_col1, #T_5c615_row2_col2, #T_5c615_row2_col3, #T_5c615_row2_col4, #T_5c615_row2_col5, #T_5c615_row2_col6, #T_5c615_row2_col7, #T_5c615_row3_col1, #T_5c615_row3_col2, #T_5c615_row3_col3, #T_5c615_row3_col4, #T_5c615_row3_col5, #T_5c615_row3_col6, #T_5c615_row3_col7, #T_5c615_row4_col2, #T_5c615_row5_col2, #T_5c615_row6_col2, #T_5c615_row7_col2, #T_5c615_row8_col2, #T_5c615_row9_col2, #T_5c615_row10_col2, #T_5c615_row11_col2, #T_5c615_row12_col2, #T_5c615_row13_col2, #T_5c615_row14_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5c615_row0_col8, #T_5c615_row1_col8, #T_5c615_row2_col8, #T_5c615_row4_col8, #T_5c615_row5_col8, #T_5c615_row6_col8, #T_5c615_row7_col8, #T_5c615_row8_col8, #T_5c615_row9_col8, #T_5c615_row10_col8, #T_5c615_row11_col8, #T_5c615_row12_col8, #T_5c615_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5c615_row3_col8, #T_5c615_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5c615" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c615_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5c615_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5c615_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5c615_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5c615_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5c615_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5c615_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5c615_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_5c615_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c615_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_5c615_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_5c615_row0_col1" class="data row0 col1" >0.9718</td>
#       <td id="T_5c615_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_5c615_row0_col3" class="data row0 col3" >0.9718</td>
#       <td id="T_5c615_row0_col4" class="data row0 col4" >0.9780</td>
#       <td id="T_5c615_row0_col5" class="data row0 col5" >0.9712</td>
#       <td id="T_5c615_row0_col6" class="data row0 col6" >0.9573</td>
#       <td id="T_5c615_row0_col7" class="data row0 col7" >0.9609</td>
#       <td id="T_5c615_row0_col8" class="data row0 col8" >0.5910</td>
#     </tr>
#     <tr>
#       <th id="T_5c615_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_5c615_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_5c615_row1_col1" class="data row1 col1" >0.9718</td>
#       <td id="T_5c615_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_5c615_row1_col3" class="data row1 col3" >0.9718</td>
#       <td id="T_5c615_row1_col4" class="data row1 col4" >0.9780</td>
#       <td id="T_5c615_row1_col5" class="data row1 col5" >0.9712</td>
#       <td id="T_5c615_row1_col6" class="data row1 col6" >0.9573</td>
#       <td id="T_5c615_row1_col7" class="data row1 col7" >0.9609</td>
#       <td id="T_5c615_row1_col8" class="data row1 col8" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_5c615_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_5c615_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_5c615_row2_col1" class="data row2 col1" >0.9718</td>
#       <td id="T_5c615_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_5c615_row2_col3" class="data row2 col3" >0.9718</td>
#       <td id="T_5c615_row2_col4" class="data row2 col4" >0.9780</td>
#       <td id="T_5c615_row2_col5" class="data row2 col5" >0.9712</td>
#       <td id="T_5c615_row2_col6" class="data row2 col6" >0.9573</td>
#       <td id="T_5c615_row2_col7" class="data row2 col7" >0.9609</td>
#       <td id="T_5c615_row2_col8" class="data row2 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_5c615_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_5c615_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_5c615_row3_col1" class="data row3 col1" >0.9718</td>
#       <td id="T_5c615_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_5c615_row3_col3" class="data row3 col3" >0.9718</td>
#       <td id="T_5c615_row3_col4" class="data row3 col4" >0.9780</td>
#       <td id="T_5c615_row3_col5" class="data row3 col5" >0.9712</td>
#       <td id="T_5c615_row3_col6" class="data row3 col6" >0.9573</td>
#       <td id="T_5c615_row3_col7" class="data row3 col7" >0.9609</td>
#       <td id="T_5c615_row3_col8" class="data row3 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_5c615_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_5c615_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5c615_row4_col1" class="data row4 col1" >0.9536</td>
#       <td id="T_5c615_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_5c615_row4_col3" class="data row4 col3" >0.9536</td>
#       <td id="T_5c615_row4_col4" class="data row4 col4" >0.9634</td>
#       <td id="T_5c615_row4_col5" class="data row4 col5" >0.9528</td>
#       <td id="T_5c615_row4_col6" class="data row4 col6" >0.9298</td>
#       <td id="T_5c615_row4_col7" class="data row4 col7" >0.9356</td>
#       <td id="T_5c615_row4_col8" class="data row4 col8" >0.0920</td>
#     </tr>
#     <tr>
#       <th id="T_5c615_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_5c615_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_5c615_row5_col1" class="data row5 col1" >0.9445</td>
#       <td id="T_5c615_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_5c615_row5_col3" class="data row5 col3" >0.9445</td>
#       <td id="T_5c615_row5_col4" class="data row5 col4" >0.9525</td>
#       <
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
# compare models using OOP
exp.compare_models()
# Out:
# <style type="text/css">
# #T_27566 th {
#   text-align: left;
# }
# #T_27566_row0_col0, #T_27566_row1_col0, #T_27566_row2_col0, #T_27566_row3_col0, #T_27566_row4_col0, #T_27566_row4_col1, #T_27566_row4_col3, #T_27566_row4_col4, #T_27566_row4_col5, #T_27566_row4_col6, #T_27566_row4_col7, #T_27566_row5_col0, #T_27566_row5_col1, #T_27566_row5_col3, #T_27566_row5_col4, #T_27566_row5_col5, #T_27566_row5_col6, #T_27566_row5_col7, #T_27566_row6_col0, #T_27566_row6_col1, #T_27566_row6_col3, #T_27566_row6_col4, #T_27566_row6_col5, #T_27566_row6_col6, #T_27566_row6_col7, #T_27566_row7_col0, #T_27566_row7_col1, #T_27566_row7_col3, #T_27566_row7_col4, #T_27566_row7_col5, #T_27566_row7_col6, #T_27566_row7_col7, #T_27566_row8_col0, #T_27566_row8_col1, #T_27566_row8_col3, #T_27566_row8_col4, #T_27566_row8_col5, #T_27566_row8_col6, #T_27566_row8_col7, #T_27566_row9_col0, #T_27566_row9_col1, #T_27566_row9_col3, #T_27566_row9_col4, #T_27566_row9_col5, #T_27566_row9_col6, #T_27566_row9_col7, #T_27566_row10_col0, #T_27566_row10_col1, #T_27566_row10_col3, #T_27566_row10_col4, #T_27566_row10_col5, #T_27566_row10_col6, #T_27566_row10_col7, #T_27566_row11_col0, #T_27566_row11_col1, #T_27566_row11_col3, #T_27566_row11_col4, #T_27566_row11_col5, #T_27566_row11_col6, #T_27566_row11_col7, #T_27566_row12_col0, #T_27566_row12_col1, #T_27566_row12_col3, #T_27566_row12_col4, #T_27566_row12_col5, #T_27566_row12_col6, #T_27566_row12_col7, #T_27566_row13_col0, #T_27566_row13_col1, #T_27566_row13_col3, #T_27566_row13_col4, #T_27566_row13_col5, #T_27566_row13_col6, #T_27566_row13_col7, #T_27566_row14_col0, #T_27566_row14_col1, #T_27566_row14_col3, #T_27566_row14_col4, #T_27566_row14_col5, #T_27566_row14_col6, #T_27566_row14_col7 {
#   text-align: left;
# }
# #T_27566_row0_col1, #T_27566_row0_col2, #T_27566_row0_col3, #T_27566_row0_col4, #T_27566_row0_col5, #T_27566_row0_col6, #T_27566_row0_col7, #T_27566_row1_col1, #T_27566_row1_col2, #T_27566_row1_col3, #T_27566_row1_col4, #T_27566_row1_col5, #T_27566_row1_col6, #T_27566_row1_col7, #T_27566_row2_col1, #T_27566_row2_col2, #T_27566_row2_col3, #T_27566_row2_col4, #T_27566_row2_col5, #T_27566_row2_col6, #T_27566_row2_col7, #T_27566_row3_col1, #T_27566_row3_col2, #T_27566_row3_col3, #T_27566_row3_col4, #T_27566_row3_col5, #T_27566_row3_col6, #T_27566_row3_col7, #T_27566_row4_col2, #T_27566_row5_col2, #T_27566_row6_col2, #T_27566_row7_col2, #T_27566_row8_col2, #T_27566_row9_col2, #T_27566_row10_col2, #T_27566_row11_col2, #T_27566_row12_col2, #T_27566_row13_col2, #T_27566_row14_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_27566_row0_col8, #T_27566_row1_col8, #T_27566_row2_col8, #T_27566_row3_col8, #T_27566_row4_col8, #T_27566_row5_col8, #T_27566_row6_col8, #T_27566_row7_col8, #T_27566_row8_col8, #T_27566_row9_col8, #T_27566_row10_col8, #T_27566_row11_col8, #T_27566_row12_col8, #T_27566_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_27566_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_27566" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27566_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_27566_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_27566_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_27566_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_27566_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_27566_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_27566_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_27566_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_27566_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27566_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_27566_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_27566_row0_col1" class="data row0 col1" >0.9718</td>
#       <td id="T_27566_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_27566_row0_col3" class="data row0 col3" >0.9718</td>
#       <td id="T_27566_row0_col4" class="data row0 col4" >0.9780</td>
#       <td id="T_27566_row0_col5" class="data row0 col5" >0.9712</td>
#       <td id="T_27566_row0_col6" class="data row0 col6" >0.9573</td>
#       <td id="T_27566_row0_col7" class="data row0 col7" >0.9609</td>
#       <td id="T_27566_row0_col8" class="data row0 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_27566_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_27566_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_27566_row1_col1" class="data row1 col1" >0.9718</td>
#       <td id="T_27566_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_27566_row1_col3" class="data row1 col3" >0.9718</td>
#       <td id="T_27566_row1_col4" class="data row1 col4" >0.9780</td>
#       <td id="T_27566_row1_col5" class="data row1 col5" >0.9712</td>
#       <td id="T_27566_row1_col6" class="data row1 col6" >0.9573</td>
#       <td id="T_27566_row1_col7" class="data row1 col7" >0.9609</td>
#       <td id="T_27566_row1_col8" class="data row1 col8" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_27566_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_27566_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_27566_row2_col1" class="data row2 col1" >0.9718</td>
#       <td id="T_27566_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_27566_row2_col3" class="data row2 col3" >0.9718</td>
#       <td id="T_27566_row2_col4" class="data row2 col4" >0.9780</td>
#       <td id="T_27566_row2_col5" class="data row2 col5" >0.9712</td>
#       <td id="T_27566_row2_col6" class="data row2 col6" >0.9573</td>
#       <td id="T_27566_row2_col7" class="data row2 col7" >0.9609</td>
#       <td id="T_27566_row2_col8" class="data row2 col8" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_27566_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_27566_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_27566_row3_col1" class="data row3 col1" >0.9718</td>
#       <td id="T_27566_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_27566_row3_col3" class="data row3 col3" >0.9718</td>
#       <td id="T_27566_row3_col4" class="data row3 col4" >0.9780</td>
#       <td id="T_27566_row3_col5" class="data row3 col5" >0.9712</td>
#       <td id="T_27566_row3_col6" class="data row3 col6" >0.9573</td>
#       <td id="T_27566_row3_col7" class="data row3 col7" >0.9609</td>
#       <td id="T_27566_row3_col8" class="data row3 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_27566_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_27566_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_27566_row4_col1" class="data row4 col1" >0.9536</td>
#       <td id="T_27566_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_27566_row4_col3" class="data row4 col3" >0.9536</td>
#       <td id="T_27566_row4_col4" class="data row4 col4" >0.9634</td>
#       <td id="T_27566_row4_col5" class="data row4 col5" >0.9528</td>
#       <td id="T_27566_row4_col6" class="data row4 col6" >0.9298</td>
#       <td id="T_27566_row4_col7" class="data row4 col7" >0.9356</td>
#       <td id="T_27566_row4_col8" class="data row4 col8" >0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_27566_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_27566_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_27566_row5_col1" class="data row5 col1" >0.9445</td>
#       <td id="T_27566_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_27566_row5_col3" class="data row5 col3" >0.9445</td>
#       <td id="T_27566_row5_col4" class="data row5 col4" >0.9525</td>
#       <
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Notice that the output between functional and OOP API is consistent. Rest of the functions in this notebook will only be shown using functional API only.

# %% [markdown]
# ## Analyze Model

# %% [markdown]
# You can use the `plot_model` function to analyzes the performance of a trained model on the test set. It may require re-training the model in certain cases.

# %%
# plot confusion matrix
plot_model(best, plot = 'confusion_matrix')

# %%
# plot AUC
plot_model(best, plot = 'auc')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %%
# check docstring to see available plots
help(plot_model)
# Out:
# Help on function plot_model in module pycaret.classification.functional:
#
# plot_model(estimator, plot: str = 'auc', scale: float = 1, save: bool = False, fold: Union[int, Any, NoneType] = None, fit_kwargs: Optional[dict] = None, plot_kwargs: Optional[dict] = None, groups: Union[str, Any, NoneType] = None, verbose: bool = True, display_format: Optional[str] = None) -> Optional[str]
#     This function analyzes the performance of a trained model on holdout set.
#     It may require re-training the model in certain cases.
#
#     Example
#     -------
#     >>> from pycaret.datasets import get_data
#     >>> juice = get_data('juice')
#     >>> from pycaret.classification import *
#     >>> exp_name = setup(data = juice,  target = 'Purchase')
#     >>> lr = create_model('lr')
#     >>> plot_model(lr, plot = 'auc')
#
#
#     estimator: scikit-learn compatible object
#         Trained model object
#
#
#     plot: str, default = 'auc'
#         List of available plots (ID - Name):
#
#         * 'pipeline' - Schematic drawing of the preprocessing pipeline
#         * 'auc' - Area Under the Curve
#         * 'threshold' - Discrimination Threshold
#         * 'pr' - Precision Recall Curve
#         * 'confusion_matrix' - Confusion Matrix
#         * 'error' - Class Prediction Error
#         * 'class_report' - Classification Report
#         * 'boundary' - Decision Boundary
#         * 'rfe' - Recursive Feature Selection
#         * 'learning' - Learning Curve
#         * 'manifold' - Manifold Learning
#         * 'calibration' - Calibration Curve
#         * 'vc' - Validation Curve
#         * 'dimension' - Dimension Learning
#         * 'feature' - Feature Importance
#         * 'feature_all' - Feature Importance (All)
#         * 'parameter' - Model Hyperparameter
#         * 'lift' - Lift Curve
#         * 'gain' - Gain Chart
#         * 'tree' - Decision Tree
#         * 'ks' - KS Statistic Plot
#
#
#     scale: float, default = 1
#         The resolution scale of the figure.
#
#
#     save: bool, default = False
#         When set to True, plot is saved in the current working directory.
#
#
#     fold: int or scikit-learn compatible CV generator, default = None
#         Controls cross-validation. If None, the CV generator in the ``fold_strategy``
#         parameter of the ``setup`` function is used. When an integer is passed,
#         it is interpreted as the 'n_splits' parameter of the CV generator in the
#         ``setup`` function.
#
#
#     fit_kwargs: dict, default = {} (empty dict)
#         Dictionary of arguments passed to the fit method of the model.
#
#
#     plot_kwargs: dict, default = {} (empty dict)
#         Dictionary of arguments passed to the visualizer class.
#             - pipeline: fontsize -> int
#
#
#     groups: str or array-like, with shape (n_samples,), default = None
#         Optional group labels when GroupKFold is used for the cross validation.
#         It takes an array with shape (n_samples, ) where n_samples is the number
#         of rows in training dataset. When string is passed, it is interpreted as
#         the column name in the dataset containing group labels.
#
#
#     verbose: bool, default = True
#         When set to False, progress bar is not displayed.
#
#
#     display_format: str, default = None
#         To display plots in Streamlit (https://www.streamlit.io/), set this to 'streamlit'.
#         Currently, not all plots are supported.
#
#
#     Returns:
#         Path to saved file, if any.
#
#
#     Warnings
#     --------
#     -   Estimators that does not support 'predict_proba' attribute cannot be used for
#         'AUC' and 'calibration' plots.
#
#     -   When the target is multiclass, 'calibration', 'threshold', 'manifold' and 'rfe'
#         plots are not available.
#
#     -   When the 'max_features' parameter of a trained model object is not equal to
#         the number of samples in training set, the 'rfe' plot is not available.

# %% [markdown]
# ## Prediction
# The `predict_model` function returns `prediction_label` and `prediction_score` (probability of the predicted class) as new columns in dataframe. When data is `None` (default), it uses the test set (created during the setup function) for scoring.

# %%
# predict on test set
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_66e45" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66e45_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_66e45_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_66e45_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_66e45_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_66e45_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_66e45_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_66e45_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_66e45_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66e45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66e45_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_66e45_row0_col1" class="data row0 col1" >0.9778</td>
#       <td id="T_66e45_row0_col2" class="data row0 col2" >0.9985</td>
#       <td id="T_66e45_row0_col3" class="data row0 col3" >0.9778</td>
#       <td id="T_66e45_row0_col4" class="data row0 col4" >0.9792</td>
#       <td id="T_66e45_row0_col5" class="data row0 col5" >0.9778</td>
#       <td id="T_66e45_row0_col6" class="data row0 col6" >0.9667</td>
#       <td id="T_66e45_row0_col7" class="data row0 col7" >0.9674</td>
#     </tr>
#   </tbody>
# </table>

# %%
# show predictions df
holdout_pred.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species  \
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 125           7.2          3.2           6.0          1.8   Iris-virginica
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 86            6.7          3.1           4.7          1.5  Iris-versicolor
# 117           7.7          3.8           6.7          2.2   Iris-virginica
#
#     prediction_label  prediction_score
# 72   Iris-versicolor            0.5203
# 125   Iris-virginica            0.9503
# 80   Iris-versicolor            0.9334
# 86   Iris-versicolor            0.7320
# 117   Iris-virginica            0.9953

# %% [markdown]
# The same function works for predicting the labels on unseen dataset. Let's create a copy of original data and drop the `Class variable`. We can then use the new data frame without labels for scoring.

# %%
# copy data and drop Class variable

new_data = data.copy()
new_data.drop('species', axis=1, inplace=True)
new_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# predict model on new_data
predictions = predict_model(best, data = new_data)
predictions.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width prediction_label  \
# 0           5.1          3.5           1.4          0.2      Iris-setosa
# 1           4.9          3.0           1.4          0.2      Iris-setosa
# 2           4.7          3.2           1.3          0.2      Iris-setosa
# 3           4.6          3.1           1.5          0.2      Iris-setosa
# 4           5.0          3.6           1.4          0.2      Iris-setosa
#
#    prediction_score
# 0            0.9775
# 1            0.9678
# 2            0.9820
# 3            0.9719
# 4            0.9813

# %% [markdown]
# ## Save Model

# %% [markdown]
# Finally, you can save the entire pipeline on disk for later use, using pycaret's `save_model` function.

# %%
# save pipeline
save_model(best, 'my_first_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['sepal_length', 'sepal_width',
#                                               'petal_length', 'petal_width'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empt...
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=123,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'my_first_pipeline.pkl')

# %%
# load pipeline
loaded_best_pipeline = load_model('my_first_pipeline')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['sepal_length', 'sepal_width',
#                                              'petal_length', 'petal_width'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=Non...
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='most_frequent'))),
#                 ('trained_model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=123,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# # 👇 Detailed function-by-function overview

# %% [markdown]
# ## ✅ Setup
# This function initializes the experiment in PyCaret and creates the transformation pipeline based on all the parameters passed in the function. Setup function must be called before executing any other function. It takes two required parameters: `data` and `target`. All the other parameters are optional and are used for configuring data preprocessing pipeline.

# %%
s = setup(data, target = 'species', session_id = 123)
# Out:
# <style type="text/css">
# #T_4eed5_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4eed5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4eed5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4eed5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4eed5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4eed5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4eed5_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4eed5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4eed5_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4eed5_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4eed5_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4eed5_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_4eed5_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4eed5_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_4eed5_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4eed5_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_4eed5_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4eed5_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_4eed5_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4eed5_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_4eed5_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4eed5_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4eed5_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4eed5_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4eed5_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4eed5_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4eed5_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4eed5_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4eed5_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4eed5_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4eed5_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4eed5_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_4eed5_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4eed5_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_4eed5_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4eed5_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_4eed5_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4eed5_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_4eed5_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4eed5_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_4eed5_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4eed5_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_4eed5_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4eed5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4eed5_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_4eed5_row19_col1" class="data row19 col1" >bf42</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To access all the variables created by the setup function such as transformed dataset, random_state, etc. you can use `get_config` method.

# %%
# check all available config
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
# lets access X_train_transformed
get_config('X_train_transformed')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 60            5.0          2.0           3.5          1.0
# 16            5.4          3.9           1.3          0.4
# 88            5.6          3.0           4.1          1.3
# 130           7.4          2.8           6.1          1.9
# 6             4.6          3.4           1.4          0.3
# ..            ...          ...           ...          ...
# 58            6.6          2.9           4.6          1.3
# 41            4.5          2.3           1.3          0.3
# 12            4.8          3.0           1.4          0.1
# 20            5.4          3.4           1.7          0.2
# 148           6.2          3.4           5.4          2.3
#
# [105 rows x 4 columns]

# %% [markdown]
# #### Random Seed
# <p>A random seed is used to ensure that results are reproducible. In other words, using this parameter makes sure that anyone who re-runs your code will get the exact same outputs. Reproducibility is an extremely important concept in data science and other fields.</p>
# <p>Depending on your specific project, you may not even need a random seed. However, there are 2 common tasks where they are used:</p>
# <ul>
# <li>
# 1. Splitting data into training/validation/test sets: random seeds ensure that the data is divided the same way every time the code is run.</li>
#
# <li>2. Model training: algorithms such as random forest and gradient boosting are non-deterministic (for a given input, the output is not always the same) and so require a random seed argument for reproducible results</li>
# </ul>

# %%
# another example: let's access seed
print("The current seed is: {}".format(get_config('seed')))

# now lets change it using set_config
set_config('seed', 786)
print("The new seed is: {}".format(get_config('seed')))
# Out:
# The current seed is: 123
# The new seed is: 786

# %% [markdown]
# All the preprocessing configurations and experiment settings/parameters are passed into the `setup` function. To see all available parameters, check the docstring:

# %%
# help(setup)

# %%
# init setup with normalize = True

s = setup(data, target = 'species', session_id = 123,
          normalize = True, normalize_method = 'minmax')
# Out:
# <style type="text/css">
# #T_0a02e_row9_col1, #T_0a02e_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0a02e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a02e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0a02e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a02e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a02e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0a02e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a02e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0a02e_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a02e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0a02e_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a02e_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_0a02e_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0a02e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_0a02e_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0a02e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_0a02e_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0a02e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_0a02e_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0a02e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_0a02e_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0a02e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_0a02e_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0a02e_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0a02e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0a02e_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0a02e_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0a02e_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0a02e_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0a02e_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0a02e_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0a02e_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_0a02e_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0a02e_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_0a02e_row14_col1" class="data row14 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0a02e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_0a02e_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0a02e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_0a02e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0a02e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_0a02e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0a02e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_0a02e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0a02e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_0a02e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0a02e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_0a02e_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0a02e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0a02e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_0a02e_row21_col1" class="data row21 col1" >d0c0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# lets check the X_train_transformed to see effect of params passed
get_config('X_train_transformed')['sepal_length'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Notice that all the values are between 0 and 1 - that is because we passed `normalize=True` in the `setup` function. If you don't remember how it compares to actual data, no problem - we can also access non-transformed values using `get_config` and then compare. See below and notice the range of values on x-axis and compare it with histogram above.

# %%
get_config('X_train')['sepal_length'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## ✅ Compare Models
# This function trains and evaluates the performance of all estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores. Metrics evaluated during CV can be accessed using the `get_metrics` function. Custom metrics can be added or removed using `add_metric` and `remove_metric` function.

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_316ad th {
#   text-align: left;
# }
# #T_316ad_row0_col0, #T_316ad_row1_col0, #T_316ad_row2_col0, #T_316ad_row2_col1, #T_316ad_row2_col3, #T_316ad_row2_col4, #T_316ad_row2_col5, #T_316ad_row2_col6, #T_316ad_row2_col7, #T_316ad_row3_col0, #T_316ad_row3_col1, #T_316ad_row3_col3, #T_316ad_row3_col4, #T_316ad_row3_col5, #T_316ad_row3_col6, #T_316ad_row3_col7, #T_316ad_row4_col0, #T_316ad_row4_col1, #T_316ad_row4_col3, #T_316ad_row4_col4, #T_316ad_row4_col5, #T_316ad_row4_col6, #T_316ad_row4_col7, #T_316ad_row5_col0, #T_316ad_row5_col1, #T_316ad_row5_col3, #T_316ad_row5_col4, #T_316ad_row5_col5, #T_316ad_row5_col6, #T_316ad_row5_col7, #T_316ad_row6_col0, #T_316ad_row6_col1, #T_316ad_row6_col3, #T_316ad_row6_col4, #T_316ad_row6_col5, #T_316ad_row6_col6, #T_316ad_row6_col7, #T_316ad_row7_col0, #T_316ad_row7_col1, #T_316ad_row7_col3, #T_316ad_row7_col4, #T_316ad_row7_col5, #T_316ad_row7_col6, #T_316ad_row7_col7, #T_316ad_row8_col0, #T_316ad_row8_col1, #T_316ad_row8_col3, #T_316ad_row8_col4, #T_316ad_row8_col5, #T_316ad_row8_col6, #T_316ad_row8_col7, #T_316ad_row9_col0, #T_316ad_row9_col1, #T_316ad_row9_col3, #T_316ad_row9_col4, #T_316ad_row9_col5, #T_316ad_row9_col6, #T_316ad_row9_col7, #T_316ad_row10_col0, #T_316ad_row10_col1, #T_316ad_row10_col3, #T_316ad_row10_col4, #T_316ad_row10_col5, #T_316ad_row10_col6, #T_316ad_row10_col7, #T_316ad_row11_col0, #T_316ad_row11_col1, #T_316ad_row11_col3, #T_316ad_row11_col4, #T_316ad_row11_col5, #T_316ad_row11_col6, #T_316ad_row11_col7, #T_316ad_row12_col0, #T_316ad_row12_col1, #T_316ad_row12_col3, #T_316ad_row12_col4, #T_316ad_row12_col5, #T_316ad_row12_col6, #T_316ad_row12_col7, #T_316ad_row13_col0, #T_316ad_row13_col1, #T_316ad_row13_col3, #T_316ad_row13_col4, #T_316ad_row13_col5, #T_316ad_row13_col6, #T_316ad_row13_col7, #T_316ad_row14_col0, #T_316ad_row14_col1, #T_316ad_row14_col3, #T_316ad_row14_col4, #T_316ad_row14_col5, #T_316ad_row14_col6, #T_316ad_row14_col7 {
#   text-align: left;
# }
# #T_316ad_row0_col1, #T_316ad_row0_col2, #T_316ad_row0_col3, #T_316ad_row0_col4, #T_316ad_row0_col5, #T_316ad_row0_col6, #T_316ad_row0_col7, #T_316ad_row1_col1, #T_316ad_row1_col2, #T_316ad_row1_col3, #T_316ad_row1_col4, #T_316ad_row1_col5, #T_316ad_row1_col6, #T_316ad_row1_col7, #T_316ad_row2_col2, #T_316ad_row3_col2, #T_316ad_row4_col2, #T_316ad_row5_col2, #T_316ad_row6_col2, #T_316ad_row7_col2, #T_316ad_row8_col2, #T_316ad_row9_col2, #T_316ad_row10_col2, #T_316ad_row11_col2, #T_316ad_row12_col2, #T_316ad_row13_col2, #T_316ad_row14_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_316ad_row0_col8, #T_316ad_row1_col8, #T_316ad_row2_col8, #T_316ad_row3_col8, #T_316ad_row4_col8, #T_316ad_row5_col8, #T_316ad_row6_col8, #T_316ad_row7_col8, #T_316ad_row8_col8, #T_316ad_row9_col8, #T_316ad_row10_col8, #T_316ad_row11_col8, #T_316ad_row12_col8, #T_316ad_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_316ad_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_316ad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_316ad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_316ad_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_316ad_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_316ad_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_316ad_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_316ad_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_316ad_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_316ad_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_316ad_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_316ad_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_316ad_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_316ad_row0_col1" class="data row0 col1" >0.9718</td>
#       <td id="T_316ad_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_316ad_row0_col3" class="data row0 col3" >0.9718</td>
#       <td id="T_316ad_row0_col4" class="data row0 col4" >0.9780</td>
#       <td id="T_316ad_row0_col5" class="data row0 col5" >0.9712</td>
#       <td id="T_316ad_row0_col6" class="data row0 col6" >0.9573</td>
#       <td id="T_316ad_row0_col7" class="data row0 col7" >0.9609</td>
#       <td id="T_316ad_row0_col8" class="data row0 col8" >0.0630</td>
#     </tr>
#     <tr>
#       <th id="T_316ad_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_316ad_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_316ad_row1_col1" class="data row1 col1" >0.9718</td>
#       <td id="T_316ad_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_316ad_row1_col3" class="data row1 col3" >0.9718</td>
#       <td id="T_316ad_row1_col4" class="data row1 col4" >0.9780</td>
#       <td id="T_316ad_row1_col5" class="data row1 col5" >0.9712</td>
#       <td id="T_316ad_row1_col6" class="data row1 col6" >0.9573</td>
#       <td id="T_316ad_row1_col7" class="data row1 col7" >0.9609</td>
#       <td id="T_316ad_row1_col8" class="data row1 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_316ad_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_316ad_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_316ad_row2_col1" class="data row2 col1" >0.9636</td>
#       <td id="T_316ad_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_316ad_row2_col3" class="data row2 col3" >0.9636</td>
#       <td id="T_316ad_row2_col4" class="data row2 col4" >0.9709</td>
#       <td id="T_316ad_row2_col5" class="data row2 col5" >0.9631</td>
#       <td id="T_316ad_row2_col6" class="data row2 col6" >0.9450</td>
#       <td id="T_316ad_row2_col7" class="data row2 col7" >0.9494</td>
#       <td id="T_316ad_row2_col8" class="data row2 col8" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_316ad_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_316ad_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_316ad_row3_col1" class="data row3 col1" >0.9536</td>
#       <td id="T_316ad_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_316ad_row3_col3" class="data row3 col3" >0.9536</td>
#       <td id="T_316ad_row3_col4" class="data row3 col4" >0.9634</td>
#       <td id="T_316ad_row3_col5" class="data row3 col5" >0.9528</td>
#       <td id="T_316ad_row3_col6" class="data row3 col6" >0.9298</td>
#       <td id="T_316ad_row3_col7" class="data row3 col7" >0.9356</td>
#       <td id="T_316ad_row3_col8" class="data row3 col8" >0.0960</td>
#     </tr>
#     <tr>
#       <th id="T_316ad_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_316ad_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_316ad_row4_col1" class="data row4 col1" >0.9445</td>
#       <td id="T_316ad_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_316ad_row4_col3" class="data row4 col3" >0.9445</td>
#       <td id="T_316ad_row4_col4" class="data row4 col4" >0.9525</td>
#       <td id="T_316ad_row4_col5" class="data row4 col5" >0.9438</td>
#       <td id="T_316ad_row4_col6" class="data row4 col6" >0.9161</td>
#       <td id="T_316ad_row4_col7" class="data row4 col7" >0.9207</td>
#       <td id="T_316ad_row4_col8" class="data row4 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_316ad_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_316ad_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_316ad_row5_col1" class="data row5 col1" >0.9445</td>
#       <td id="T_316ad_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_316ad_row5_col3" class="data row5 col3" >0.9445</td>
#       <td id="T_316ad_row5_col4" class="data row5 col4" >0.9586</td>
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %% [markdown]
# `compare_models` by default uses all the estimators in model library (all except models with `Turbo=False`) . To see all available models you can use the function `models()`

# %%
# check available models
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %% [markdown]
# You can use the `include` and `exclude` parameter in the `compare_models` to train only select model or exclude specific models from training by passing the model id's in `exclude` parameter.

# %%
compare_tree_models = compare_models(include = ['dt', 'rf', 'et', 'gbc', 'xgboost', 'lightgbm'])
# Out:
# <style type="text/css">
# #T_a9269 th {
#   text-align: left;
# }
# #T_a9269_row0_col0, #T_a9269_row1_col0, #T_a9269_row1_col1, #T_a9269_row1_col3, #T_a9269_row1_col4, #T_a9269_row1_col5, #T_a9269_row1_col6, #T_a9269_row1_col7, #T_a9269_row2_col0, #T_a9269_row2_col1, #T_a9269_row2_col3, #T_a9269_row2_col4, #T_a9269_row2_col5, #T_a9269_row2_col6, #T_a9269_row2_col7, #T_a9269_row3_col0, #T_a9269_row3_col1, #T_a9269_row3_col3, #T_a9269_row3_col4, #T_a9269_row3_col5, #T_a9269_row3_col6, #T_a9269_row3_col7, #T_a9269_row4_col0, #T_a9269_row4_col1, #T_a9269_row4_col3, #T_a9269_row4_col4, #T_a9269_row4_col5, #T_a9269_row4_col6, #T_a9269_row4_col7, #T_a9269_row5_col0, #T_a9269_row5_col1, #T_a9269_row5_col3, #T_a9269_row5_col4, #T_a9269_row5_col5, #T_a9269_row5_col6, #T_a9269_row5_col7 {
#   text-align: left;
# }
# #T_a9269_row0_col1, #T_a9269_row0_col2, #T_a9269_row0_col3, #T_a9269_row0_col4, #T_a9269_row0_col5, #T_a9269_row0_col6, #T_a9269_row0_col7, #T_a9269_row1_col2, #T_a9269_row2_col2, #T_a9269_row3_col2, #T_a9269_row4_col2, #T_a9269_row5_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a9269_row0_col8, #T_a9269_row1_col8, #T_a9269_row3_col8, #T_a9269_row4_col8, #T_a9269_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a9269_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a9269" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9269_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a9269_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a9269_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a9269_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a9269_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a9269_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a9269_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a9269_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a9269_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9269_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_a9269_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a9269_row0_col1" class="data row0 col1" >0.9536</td>
#       <td id="T_a9269_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_a9269_row0_col3" class="data row0 col3" >0.9536</td>
#       <td id="T_a9269_row0_col4" class="data row0 col4" >0.9634</td>
#       <td id="T_a9269_row0_col5" class="data row0 col5" >0.9528</td>
#       <td id="T_a9269_row0_col6" class="data row0 col6" >0.9298</td>
#       <td id="T_a9269_row0_col7" class="data row0 col7" >0.9356</td>
#       <td id="T_a9269_row0_col8" class="data row0 col8" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_a9269_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_a9269_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_a9269_row1_col1" class="data row1 col1" >0.9445</td>
#       <td id="T_a9269_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_a9269_row1_col3" class="data row1 col3" >0.9445</td>
#       <td id="T_a9269_row1_col4" class="data row1 col4" >0.9586</td>
#       <td id="T_a9269_row1_col5" class="data row1 col5" >0.9426</td>
#       <td id="T_a9269_row1_col6" class="data row1 col6" >0.9161</td>
#       <td id="T_a9269_row1_col7" class="data row1 col7" >0.9246</td>
#       <td id="T_a9269_row1_col8" class="data row1 col8" >0.2080</td>
#     </tr>
#     <tr>
#       <th id="T_a9269_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_a9269_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_a9269_row2_col1" class="data row2 col1" >0.9264</td>
#       <td id="T_a9269_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_a9269_row2_col3" class="data row2 col3" >0.9264</td>
#       <td id="T_a9269_row2_col4" class="data row2 col4" >0.9502</td>
#       <td id="T_a9269_row2_col5" class="data row2 col5" >0.9201</td>
#       <td id="T_a9269_row2_col6" class="data row2 col6" >0.8886</td>
#       <td id="T_a9269_row2_col7" class="data row2 col7" >0.9040</td>
#       <td id="T_a9269_row2_col8" class="data row2 col8" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_a9269_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_a9269_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_a9269_row3_col1" class="data row3 col1" >0.9264</td>
#       <td id="T_a9269_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_a9269_row3_col3" class="data row3 col3" >0.9264</td>
#       <td id="T_a9269_row3_col4" class="data row3 col4" >0.9343</td>
#       <td id="T_a9269_row3_col5" class="data row3 col5" >0.9232</td>
#       <td id="T_a9269_row3_col6" class="data row3 col6" >0.8886</td>
#       <td id="T_a9269_row3_col7" class="data row3 col7" >0.8956</td>
#       <td id="T_a9269_row3_col8" class="data row3 col8" >0.2360</td>
#     </tr>
#     <tr>
#       <th id="T_a9269_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_a9269_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a9269_row4_col1" class="data row4 col1" >0.9264</td>
#       <td id="T_a9269_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_a9269_row4_col3" class="data row4 col3" >0.9264</td>
#       <td id="T_a9269_row4_col4" class="data row4 col4" >0.9343</td>
#       <td id="T_a9269_row4_col5" class="data row4 col5" >0.9232</td>
#       <td id="T_a9269_row4_col6" class="data row4 col6" >0.8886</td>
#       <td id="T_a9269_row4_col7" class="data row4 col7" >0.8956</td>
#       <td id="T_a9269_row4_col8" class="data row4 col8" >0.2770</td>
#     </tr>
#     <tr>
#       <th id="T_a9269_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_a9269_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a9269_row5_col1" class="data row5 col1" >0.9255</td>
#       <td id="T_a9269_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_a9269_row5_col3" class="data row5 col3" >0.9255</td>
#       <td id="T_a9269_row5_col4" class="data row5 col4" >0.9360</td>
#       <td id="T_a9269_row5_col5" class="data row5 col5" >0.9239</td>
#       <td id="T_a9269_row5_col6" class="data row5 col6" >0.8870</td>
#       <td id="T_a9269_row5_col7" class="data row5 col7" >0.8937</td>
#       <td id="T_a9269_row5_col8" class="data row5 col8" >0.0640</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
compare_tree_models
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# The function above has return trained model object as an output. The scoring grid is only displayed and not returned. If you need access to the scoring grid you can use `pull` function to access the dataframe.

# %%
compare_tree_models_results = pull()
compare_tree_models_results
# Out:
#                                     Model  Accuracy  AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9536  0.0  0.9536  0.9634
# et                 Extra Trees Classifier    0.9445  0.0  0.9445  0.9586
# dt               Decision Tree Classifier    0.9264  0.0  0.9264  0.9502
# rf               Random Forest Classifier    0.9264  0.0  0.9264  0.9343
# gbc          Gradient Boosting Classifier    0.9264  0.0  0.9264  0.9343
# xgboost         Extreme Gradient Boosting    0.9255  0.0  0.9255  0.9360
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.9528  0.9298  0.9356     0.094
# et        0.9426  0.9161  0.9246     0.208
# dt        0.9201  0.8886  0.9040     0.037
# rf        0.9232  0.8886  0.8956     0.236
# gbc       0.9232  0.8886  0.8956     0.277
# xgboost   0.9239  0.8870  0.8937     0.064

# %% [markdown]
# By default `compare_models` return the single best performing model based on the metric defined in the `sort` parameter. Let's change our code to return 3 top models based on `Recall`.

# %%
best_recall_models_top3 = compare_models(sort = 'Recall', n_select = 3)
# Out:
# <style type="text/css">
# #T_35207 th {
#   text-align: left;
# }
# #T_35207_row0_col0, #T_35207_row1_col0, #T_35207_row2_col0, #T_35207_row2_col1, #T_35207_row2_col3, #T_35207_row2_col4, #T_35207_row2_col5, #T_35207_row2_col6, #T_35207_row2_col7, #T_35207_row3_col0, #T_35207_row3_col1, #T_35207_row3_col3, #T_35207_row3_col4, #T_35207_row3_col5, #T_35207_row3_col6, #T_35207_row3_col7, #T_35207_row4_col0, #T_35207_row4_col1, #T_35207_row4_col3, #T_35207_row4_col4, #T_35207_row4_col5, #T_35207_row4_col6, #T_35207_row4_col7, #T_35207_row5_col0, #T_35207_row5_col1, #T_35207_row5_col3, #T_35207_row5_col4, #T_35207_row5_col5, #T_35207_row5_col6, #T_35207_row5_col7, #T_35207_row6_col0, #T_35207_row6_col1, #T_35207_row6_col3, #T_35207_row6_col4, #T_35207_row6_col5, #T_35207_row6_col6, #T_35207_row6_col7, #T_35207_row7_col0, #T_35207_row7_col1, #T_35207_row7_col3, #T_35207_row7_col4, #T_35207_row7_col5, #T_35207_row7_col6, #T_35207_row7_col7, #T_35207_row8_col0, #T_35207_row8_col1, #T_35207_row8_col3, #T_35207_row8_col4, #T_35207_row8_col5, #T_35207_row8_col6, #T_35207_row8_col7, #T_35207_row9_col0, #T_35207_row9_col1, #T_35207_row9_col3, #T_35207_row9_col4, #T_35207_row9_col5, #T_35207_row9_col6, #T_35207_row9_col7, #T_35207_row10_col0, #T_35207_row10_col1, #T_35207_row10_col3, #T_35207_row10_col4, #T_35207_row10_col5, #T_35207_row10_col6, #T_35207_row10_col7, #T_35207_row11_col0, #T_35207_row11_col1, #T_35207_row11_col3, #T_35207_row11_col4, #T_35207_row11_col5, #T_35207_row11_col6, #T_35207_row11_col7, #T_35207_row12_col0, #T_35207_row12_col1, #T_35207_row12_col3, #T_35207_row12_col4, #T_35207_row12_col5, #T_35207_row12_col6, #T_35207_row12_col7, #T_35207_row13_col0, #T_35207_row13_col1, #T_35207_row13_col3, #T_35207_row13_col4, #T_35207_row13_col5, #T_35207_row13_col6, #T_35207_row13_col7, #T_35207_row14_col0, #T_35207_row14_col1, #T_35207_row14_col3, #T_35207_row14_col4, #T_35207_row14_col5, #T_35207_row14_col6, #T_35207_row14_col7 {
#   text-align: left;
# }
# #T_35207_row0_col1, #T_35207_row0_col2, #T_35207_row0_col3, #T_35207_row0_col4, #T_35207_row0_col5, #T_35207_row0_col6, #T_35207_row0_col7, #T_35207_row1_col1, #T_35207_row1_col2, #T_35207_row1_col3, #T_35207_row1_col4, #T_35207_row1_col5, #T_35207_row1_col6, #T_35207_row1_col7, #T_35207_row2_col2, #T_35207_row3_col2, #T_35207_row4_col2, #T_35207_row5_col2, #T_35207_row6_col2, #T_35207_row7_col2, #T_35207_row8_col2, #T_35207_row9_col2, #T_35207_row10_col2, #T_35207_row11_col2, #T_35207_row12_col2, #T_35207_row13_col2, #T_35207_row14_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_35207_row0_col8, #T_35207_row1_col8, #T_35207_row2_col8, #T_35207_row3_col8, #T_35207_row4_col8, #T_35207_row5_col8, #T_35207_row6_col8, #T_35207_row7_col8, #T_35207_row8_col8, #T_35207_row9_col8, #T_35207_row10_col8, #T_35207_row11_col8, #T_35207_row12_col8, #T_35207_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_35207_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_35207" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35207_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35207_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_35207_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_35207_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_35207_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_35207_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_35207_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_35207_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_35207_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35207_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_35207_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_35207_row0_col1" class="data row0 col1" >0.9718</td>
#       <td id="T_35207_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_35207_row0_col3" class="data row0 col3" >0.9718</td>
#       <td id="T_35207_row0_col4" class="data row0 col4" >0.9780</td>
#       <td id="T_35207_row0_col5" class="data row0 col5" >0.9712</td>
#       <td id="T_35207_row0_col6" class="data row0 col6" >0.9573</td>
#       <td id="T_35207_row0_col7" class="data row0 col7" >0.9609</td>
#       <td id="T_35207_row0_col8" class="data row0 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_35207_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_35207_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_35207_row1_col1" class="data row1 col1" >0.9718</td>
#       <td id="T_35207_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_35207_row1_col3" class="data row1 col3" >0.9718</td>
#       <td id="T_35207_row1_col4" class="data row1 col4" >0.9780</td>
#       <td id="T_35207_row1_col5" class="data row1 col5" >0.9712</td>
#       <td id="T_35207_row1_col6" class="data row1 col6" >0.9573</td>
#       <td id="T_35207_row1_col7" class="data row1 col7" >0.9609</td>
#       <td id="T_35207_row1_col8" class="data row1 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_35207_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_35207_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_35207_row2_col1" class="data row2 col1" >0.9636</td>
#       <td id="T_35207_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_35207_row2_col3" class="data row2 col3" >0.9636</td>
#       <td id="T_35207_row2_col4" class="data row2 col4" >0.9709</td>
#       <td id="T_35207_row2_col5" class="data row2 col5" >0.9631</td>
#       <td id="T_35207_row2_col6" class="data row2 col6" >0.9450</td>
#       <td id="T_35207_row2_col7" class="data row2 col7" >0.9494</td>
#       <td id="T_35207_row2_col8" class="data row2 col8" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_35207_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_35207_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_35207_row3_col1" class="data row3 col1" >0.9536</td>
#       <td id="T_35207_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_35207_row3_col3" class="data row3 col3" >0.9536</td>
#       <td id="T_35207_row3_col4" class="data row3 col4" >0.9634</td>
#       <td id="T_35207_row3_col5" class="data row3 col5" >0.9528</td>
#       <td id="T_35207_row3_col6" class="data row3 col6" >0.9298</td>
#       <td id="T_35207_row3_col7" class="data row3 col7" >0.9356</td>
#       <td id="T_35207_row3_col8" class="data row3 col8" >0.3860</td>
#     </tr>
#     <tr>
#       <th id="T_35207_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_35207_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_35207_row4_col1" class="data row4 col1" >0.9445</td>
#       <td id="T_35207_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_35207_row4_col3" class="data row4 col3" >0.9445</td>
#       <td id="T_35207_row4_col4" class="data row4 col4" >0.9525</td>
#       <td id="T_35207_row4_col5" class="data row4 col5" >0.9438</td>
#       <td id="T_35207_row4_col6" class="data row4 col6" >0.9161</td>
#       <td id="T_35207_row4_col7" class="data row4 col7" >0.9207</td>
#       <td id="T_35207_row4_col8" class="data row4 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_35207_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_35207_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_35207_row5_col1" class="data row5 col1" >0.9445</td>
#       <td id="T_35207_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_35207_row5_col3" class="data row5 col3" >0.9445</td>
#       <td id="T_35207_row5_col4" class="data row5 col4" >0.9586</td>
# Processing:   0%|          | 0/67 [00:00<?, ?it/s]

# %%
# list of top 3 models by Recall
best_recall_models_top3
# Out:
# [QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                store_covariance=False, tol=0.0001),
#  LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                             priors=None, shrinkage=None, solver='svd',
#                             store_covariance=False, tol=0.0001),
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                       weights='uniform')]

# %% [markdown]
# Some other parameters that you might find very useful in `compare_models` are:
#
# - fold
# - cross_validation
# - budget_time
# - errors
# - probability_threshold
# - parallel
#
# You can check the docstring of the function for more info.

# %%
# help(compare_models)

# %% [markdown]
# ## ✅ Create Model
# This function trains and evaluates the performance of a given estimator using cross-validation. The output of this function is a scoring grid with CV scores by fold. Metrics evaluated during CV can be accessed using the `get_metrics` function. Custom metrics can be added or removed using `add_metric` and `remove_metric` function. All the available models can be accessed using the models function.

# %%
# check all the available models
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
# train logistic regression with default fold=10
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_0614b_row10_col0, #T_0614b_row10_col1, #T_0614b_row10_col2, #T_0614b_row10_col3, #T_0614b_row10_col4, #T_0614b_row10_col5, #T_0614b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0614b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0614b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0614b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0614b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0614b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0614b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0614b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0614b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0614b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0614b_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_0614b_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_0614b_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_0614b_row0_col3" class="data row0 col3" >0.9273</td>
#       <td id="T_0614b_row0_col4" class="data row0 col4" >0.9076</td>
#       <td id="T_0614b_row0_col5" class="data row0 col5" >0.8625</td>
#       <td id="T_0614b_row0_col6" class="data row0 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0614b_row1_col0" class="data row1 col0" >0.8182</td>
#       <td id="T_0614b_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_0614b_row1_col2" class="data row1 col2" >0.8182</td>
#       <td id="T_0614b_row1_col3" class="data row1 col3" >0.8182</td>
#       <td id="T_0614b_row1_col4" class="data row1 col4" >0.8182</td>
#       <td id="T_0614b_row1_col5" class="data row1 col5" >0.7250</td>
#       <td id="T_0614b_row1_col6" class="data row1 col6" >0.7250</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0614b_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_0614b_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_0614b_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_0614b_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_0614b_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_0614b_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_0614b_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0614b_row3_col0" class="data row3 col0" >0.6364</td>
#       <td id="T_0614b_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_0614b_row3_col2" class="data row3 col2" >0.6364</td>
#       <td id="T_0614b_row3_col3" class="data row3 col3" >0.6364</td>
#       <td id="T_0614b_row3_col4" class="data row3 col4" >0.6364</td>
#       <td id="T_0614b_row3_col5" class="data row3 col5" >0.4500</td>
#       <td id="T_0614b_row3_col6" class="data row3 col6" >0.4500</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0614b_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_0614b_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_0614b_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_0614b_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_0614b_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_0614b_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_0614b_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0614b_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_0614b_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_0614b_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_0614b_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_0614b_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_0614b_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_0614b_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0614b_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_0614b_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_0614b_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_0614b_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_0614b_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_0614b_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_0614b_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0614b_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_0614b_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_0614b_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_0614b_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_0614b_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_0614b_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_0614b_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0614b_row8_col0" class="data row8 col0" >0.9000</td>
#       <td id="T_0614b_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_0614b_row8_col2" class="data row8 col2" >0.9000</td>
#       <td id="T_0614b_row8_col3" class="data row8 col3" >0.9250</td>
#       <td id="T_0614b_row8_col4" class="data row8 col4" >0.8971</td>
#       <td id="T_0614b_row8_col5" class="data row8 col5" >0.8485</td>
#       <td id="T_0614b_row8_col6" class="data row8 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0614b_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_0614b_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_0614b_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_0614b_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_0614b_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_0614b_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_0614b_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0614b_row10_col0" class="data row10 col0" >0.9073</td>
#       <td id="T_0614b_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_0614b_row10_col2" class="data row10 col2" >0.9073</td>
#       <td id="T_0614b_row10_col3" class="data row10 col3" >0.9159</td>
#       <td id="T_0614b_row10_col4" class="data row10 col4" >0.9064</td>
#       <td id="T_0614b_row10_col5" class="data row10 col5" >0.8597</td>
#       <td id="T_0614b_row10_col6" class="data row10 col6" >0.8645</td>
#     </tr>
#     <tr>
#       <th id="T_0614b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0614b_row11_col0" class="data row11 col0" >0.1076</td>
#       <td id="T_0614b_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_0614b_row11_col2" class="data row11 col2" >0.1076</td>
#       <td id="T_0614b_row11_col3" class="data row11 col3" >0.1079</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# The function above has return trained model object as an output. The scoring grid is only displayed and not returned. If you need access to the scoring grid you can use `pull` function to access the dataframe.

# %%
# train logistic regression with fold=3
lr = create_model('lr', fold=3)
# Out:
# <style type="text/css">
# #T_2db84_row3_col0, #T_2db84_row3_col1, #T_2db84_row3_col2, #T_2db84_row3_col3, #T_2db84_row3_col4, #T_2db84_row3_col5, #T_2db84_row3_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2db84" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2db84_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2db84_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2db84_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2db84_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2db84_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2db84_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2db84_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2db84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2db84_row0_col0" class="data row0 col0" >0.9143</td>
#       <td id="T_2db84_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_2db84_row0_col2" class="data row0 col2" >0.9143</td>
#       <td id="T_2db84_row0_col3" class="data row0 col3" >0.9158</td>
#       <td id="T_2db84_row0_col4" class="data row0 col4" >0.9140</td>
#       <td id="T_2db84_row0_col5" class="data row0 col5" >0.8712</td>
#       <td id="T_2db84_row0_col6" class="data row0 col6" >0.8722</td>
#     </tr>
#     <tr>
#       <th id="T_2db84_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2db84_row1_col0" class="data row1 col0" >0.8857</td>
#       <td id="T_2db84_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_2db84_row1_col2" class="data row1 col2" >0.8857</td>
#       <td id="T_2db84_row1_col3" class="data row1 col3" >0.8922</td>
#       <td id="T_2db84_row1_col4" class="data row1 col4" >0.8849</td>
#       <td id="T_2db84_row1_col5" class="data row1 col5" >0.8284</td>
#       <td id="T_2db84_row1_col6" class="data row1 col6" >0.8325</td>
#     </tr>
#     <tr>
#       <th id="T_2db84_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2db84_row2_col0" class="data row2 col0" >0.9714</td>
#       <td id="T_2db84_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_2db84_row2_col2" class="data row2 col2" >0.9714</td>
#       <td id="T_2db84_row2_col3" class="data row2 col3" >0.9736</td>
#       <td id="T_2db84_row2_col4" class="data row2 col4" >0.9713</td>
#       <td id="T_2db84_row2_col5" class="data row2 col5" >0.9571</td>
#       <td id="T_2db84_row2_col6" class="data row2 col6" >0.9582</td>
#     </tr>
#     <tr>
#       <th id="T_2db84_level0_row3" class="row_heading level0 row3" >Mean</th>
#       <td id="T_2db84_row3_col0" class="data row3 col0" >0.9238</td>
#       <td id="T_2db84_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_2db84_row3_col2" class="data row3 col2" >0.9238</td>
#       <td id="T_2db84_row3_col3" class="data row3 col3" >0.9272</td>
#       <td id="T_2db84_row3_col4" class="data row3 col4" >0.9234</td>
#       <td id="T_2db84_row3_col5" class="data row3 col5" >0.8856</td>
#       <td id="T_2db84_row3_col6" class="data row3 col6" >0.8877</td>
#     </tr>
#     <tr>
#       <th id="T_2db84_level0_row4" class="row_heading level0 row4" >Std</th>
#       <td id="T_2db84_row4_col0" class="data row4 col0" >0.0356</td>
#       <td id="T_2db84_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_2db84_row4_col2" class="data row4 col2" >0.0356</td>
#       <td id="T_2db84_row4_col3" class="data row4 col3" >0.0342</td>
#       <td id="T_2db84_row4_col4" class="data row4 col4" >0.0359</td>
#       <td id="T_2db84_row4_col5" class="data row4 col5" >0.0535</td>
#       <td id="T_2db84_row4_col6" class="data row4 col6" >0.0525</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# train logistic regression with specific model parameters
create_model('lr', C = 0.5, l1_ratio = 0.15)
# Out:
# <style type="text/css">
# #T_80f38_row10_col0, #T_80f38_row10_col1, #T_80f38_row10_col2, #T_80f38_row10_col3, #T_80f38_row10_col4, #T_80f38_row10_col5, #T_80f38_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_80f38" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80f38_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_80f38_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_80f38_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_80f38_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_80f38_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_80f38_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_80f38_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80f38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80f38_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_80f38_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_80f38_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_80f38_row0_col3" class="data row0 col3" >0.9273</td>
#       <td id="T_80f38_row0_col4" class="data row0 col4" >0.9076</td>
#       <td id="T_80f38_row0_col5" class="data row0 col5" >0.8625</td>
#       <td id="T_80f38_row0_col6" class="data row0 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80f38_row1_col0" class="data row1 col0" >0.8182</td>
#       <td id="T_80f38_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_80f38_row1_col2" class="data row1 col2" >0.8182</td>
#       <td id="T_80f38_row1_col3" class="data row1 col3" >0.8182</td>
#       <td id="T_80f38_row1_col4" class="data row1 col4" >0.8182</td>
#       <td id="T_80f38_row1_col5" class="data row1 col5" >0.7250</td>
#       <td id="T_80f38_row1_col6" class="data row1 col6" >0.7250</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80f38_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_80f38_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_80f38_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_80f38_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_80f38_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_80f38_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_80f38_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80f38_row3_col0" class="data row3 col0" >0.7273</td>
#       <td id="T_80f38_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_80f38_row3_col2" class="data row3 col2" >0.7273</td>
#       <td id="T_80f38_row3_col3" class="data row3 col3" >0.7333</td>
#       <td id="T_80f38_row3_col4" class="data row3 col4" >0.7229</td>
#       <td id="T_80f38_row3_col5" class="data row3 col5" >0.5875</td>
#       <td id="T_80f38_row3_col6" class="data row3 col6" >0.5950</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80f38_row4_col0" class="data row4 col0" >0.9091</td>
#       <td id="T_80f38_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_80f38_row4_col2" class="data row4 col2" >0.9091</td>
#       <td id="T_80f38_row4_col3" class="data row4 col3" >0.9273</td>
#       <td id="T_80f38_row4_col4" class="data row4 col4" >0.9076</td>
#       <td id="T_80f38_row4_col5" class="data row4 col5" >0.8625</td>
#       <td id="T_80f38_row4_col6" class="data row4 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80f38_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_80f38_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_80f38_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_80f38_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_80f38_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_80f38_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_80f38_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80f38_row6_col0" class="data row6 col0" >0.9000</td>
#       <td id="T_80f38_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_80f38_row6_col2" class="data row6 col2" >0.9000</td>
#       <td id="T_80f38_row6_col3" class="data row6 col3" >0.9250</td>
#       <td id="T_80f38_row6_col4" class="data row6 col4" >0.8971</td>
#       <td id="T_80f38_row6_col5" class="data row6 col5" >0.8485</td>
#       <td id="T_80f38_row6_col6" class="data row6 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80f38_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_80f38_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_80f38_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_80f38_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_80f38_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_80f38_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_80f38_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80f38_row8_col0" class="data row8 col0" >0.9000</td>
#       <td id="T_80f38_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_80f38_row8_col2" class="data row8 col2" >0.9000</td>
#       <td id="T_80f38_row8_col3" class="data row8 col3" >0.9250</td>
#       <td id="T_80f38_row8_col4" class="data row8 col4" >0.8971</td>
#       <td id="T_80f38_row8_col5" class="data row8 col5" >0.8485</td>
#       <td id="T_80f38_row8_col6" class="data row8 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80f38_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_80f38_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_80f38_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_80f38_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_80f38_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_80f38_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_80f38_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_80f38_row10_col0" class="data row10 col0" >0.8973</td>
#       <td id="T_80f38_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_80f38_row10_col2" class="data row10 col2" >0.8973</td>
#       <td id="T_80f38_row10_col3" class="data row10 col3" >0.9108</td>
#       <td id="T_80f38_row10_col4" class="data row10 col4" >0.8955</td>
#       <td id="T_80f38_row10_col5" class="data row10 col5" >0.8445</td>
#       <td id="T_80f38_row10_col6" class="data row10 col6" >0.8525</td>
#     </tr>
#     <tr>
#       <th id="T_80f38_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_80f38_row11_col0" class="data row11 col0" >0.0753</td>
#       <td id="T_80f38_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_80f38_row11_col2" class="data row11 col2" >0.0753</td>
#       <td id="T_80f38_row11_col3" class="data row11 col3" >0.0758</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# LogisticRegression(C=0.5, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=0.15, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# train lr and return train score as well alongwith CV
create_model('lr', return_train_score=True)
# Out:
# <style type="text/css">
# #T_6d91f_row20_col0, #T_6d91f_row20_col1, #T_6d91f_row20_col2, #T_6d91f_row20_col3, #T_6d91f_row20_col4, #T_6d91f_row20_col5, #T_6d91f_row20_col6, #T_6d91f_row22_col0, #T_6d91f_row22_col1, #T_6d91f_row22_col2, #T_6d91f_row22_col3, #T_6d91f_row22_col4, #T_6d91f_row22_col5, #T_6d91f_row22_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6d91f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d91f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6d91f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6d91f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6d91f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6d91f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6d91f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6d91f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d91f_level0_row0" class="row_heading level0 row0" rowspan="10">CV-Train</th>
#       <th id="T_6d91f_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_6d91f_row0_col0" class="data row0 col0" >0.9149</td>
#       <td id="T_6d91f_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_6d91f_row0_col2" class="data row0 col2" >0.9149</td>
#       <td id="T_6d91f_row0_col3" class="data row0 col3" >0.9159</td>
#       <td id="T_6d91f_row0_col4" class="data row0 col4" >0.9148</td>
#       <td id="T_6d91f_row0_col5" class="data row0 col5" >0.8723</td>
#       <td id="T_6d91f_row0_col6" class="data row0 col6" >0.8729</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_6d91f_row1_col0" class="data row1 col0" >0.9255</td>
#       <td id="T_6d91f_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_6d91f_row1_col2" class="data row1 col2" >0.9255</td>
#       <td id="T_6d91f_row1_col3" class="data row1 col3" >0.9258</td>
#       <td id="T_6d91f_row1_col4" class="data row1 col4" >0.9255</td>
#       <td id="T_6d91f_row1_col5" class="data row1 col5" >0.8883</td>
#       <td id="T_6d91f_row1_col6" class="data row1 col6" >0.8884</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_6d91f_row2_col0" class="data row2 col0" >0.9255</td>
#       <td id="T_6d91f_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_6d91f_row2_col2" class="data row2 col2" >0.9255</td>
#       <td id="T_6d91f_row2_col3" class="data row2 col3" >0.9279</td>
#       <td id="T_6d91f_row2_col4" class="data row2 col4" >0.9254</td>
#       <td id="T_6d91f_row2_col5" class="data row2 col5" >0.8883</td>
#       <td id="T_6d91f_row2_col6" class="data row2 col6" >0.8896</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_6d91f_row3_col0" class="data row3 col0" >0.9468</td>
#       <td id="T_6d91f_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_6d91f_row3_col2" class="data row3 col2" >0.9468</td>
#       <td id="T_6d91f_row3_col3" class="data row3 col3" >0.9471</td>
#       <td id="T_6d91f_row3_col4" class="data row3 col4" >0.9468</td>
#       <td id="T_6d91f_row3_col5" class="data row3 col5" >0.9202</td>
#       <td id="T_6d91f_row3_col6" class="data row3 col6" >0.9204</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_6d91f_row4_col0" class="data row4 col0" >0.9043</td>
#       <td id="T_6d91f_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_6d91f_row4_col2" class="data row4 col2" >0.9043</td>
#       <td id="T_6d91f_row4_col3" class="data row4 col3" >0.9065</td>
#       <td id="T_6d91f_row4_col4" class="data row4 col4" >0.9040</td>
#       <td id="T_6d91f_row4_col5" class="data row4 col5" >0.8564</td>
#       <td id="T_6d91f_row4_col6" class="data row4 col6" >0.8577</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_6d91f_row5_col0" class="data row5 col0" >0.9158</td>
#       <td id="T_6d91f_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_6d91f_row5_col2" class="data row5 col2" >0.9158</td>
#       <td id="T_6d91f_row5_col3" class="data row5 col3" >0.9168</td>
#       <td id="T_6d91f_row5_col4" class="data row5 col4" >0.9157</td>
#       <td id="T_6d91f_row5_col5" class="data row5 col5" >0.8737</td>
#       <td id="T_6d91f_row5_col6" class="data row5 col6" >0.8743</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row6" class="row_heading level1 row6" >6</th>
#       <td id="T_6d91f_row6_col0" class="data row6 col0" >0.9053</td>
#       <td id="T_6d91f_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_6d91f_row6_col2" class="data row6 col2" >0.9053</td>
#       <td id="T_6d91f_row6_col3" class="data row6 col3" >0.9074</td>
#       <td id="T_6d91f_row6_col4" class="data row6 col4" >0.9051</td>
#       <td id="T_6d91f_row6_col5" class="data row6 col5" >0.8579</td>
#       <td id="T_6d91f_row6_col6" class="data row6 col6" >0.8592</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row7" class="row_heading level1 row7" >7</th>
#       <td id="T_6d91f_row7_col0" class="data row7 col0" >0.9158</td>
#       <td id="T_6d91f_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_6d91f_row7_col2" class="data row7 col2" >0.9158</td>
#       <td id="T_6d91f_row7_col3" class="data row7 col3" >0.9158</td>
#       <td id="T_6d91f_row7_col4" class="data row7 col4" >0.9158</td>
#       <td id="T_6d91f_row7_col5" class="data row7 col5" >0.8737</td>
#       <td id="T_6d91f_row7_col6" class="data row7 col6" >0.8737</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row8" class="row_heading level1 row8" >8</th>
#       <td id="T_6d91f_row8_col0" class="data row8 col0" >0.9158</td>
#       <td id="T_6d91f_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_6d91f_row8_col2" class="data row8 col2" >0.9158</td>
#       <td id="T_6d91f_row8_col3" class="data row8 col3" >0.9168</td>
#       <td id="T_6d91f_row8_col4" class="data row8 col4" >0.9157</td>
#       <td id="T_6d91f_row8_col5" class="data row8 col5" >0.8737</td>
#       <td id="T_6d91f_row8_col6" class="data row8 col6" >0.8743</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level1_row9" class="row_heading level1 row9" >9</th>
#       <td id="T_6d91f_row9_col0" class="data row9 col0" >0.9053</td>
#       <td id="T_6d91f_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_6d91f_row9_col2" class="data row9 col2" >0.9053</td>
#       <td id="T_6d91f_row9_col3" class="data row9 col3" >0.9074</td>
#       <td id="T_6d91f_row9_col4" class="data row9 col4" >0.9051</td>
#       <td id="T_6d91f_row9_col5" class="data row9 col5" >0.8579</td>
#       <td id="T_6d91f_row9_col6" class="data row9 col6" >0.8592</td>
#     </tr>
#     <tr>
#       <th id="T_6d91f_level0_row10" class="row_heading level0 row10" rowspan="10">CV-Val</th>
#       <th id="T_6d91f_level1_row10" class="row_heading level1 row10" >0</th>
#       <td id="T_6d91f_row10_col0" class="data row10 col0" >0.9091</td>
#       <td id="T_6d91f_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_6d91f_row10_col2" class="data row10 col2" >0.9091</td>
#       <td id="T_6d91f_row10_col3" class="data row10 col3" >0.9273</td>
#       <td id="T_6d91f_row10_col4" class="data row10 col4" >0.9076</td>
#       <td id="T_6d91f_row10_col5" class="data row10 col5" >0.8625</td>
#       <td id="T_6d91f_row10_col6" class="data row1
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# Some other parameters that you might find very useful in `create_model` are:
#
# - cross_validation
# - engine
# - fit_kwargs
# - groups
#
# You can check the docstring of the function for more info.

# %%
# help(create_model)

# %% [markdown]
# ## ✅ Tune Model
#
# This function tunes the hyperparameters of the model. The output of this function is a scoring grid with cross-validated scores by fold. The best model is selected based on the metric defined in optimize parameter. Metrics evaluated during cross-validation can be accessed using the `get_metrics` function. Custom metrics can be added or removed using `add_metric` and `remove_metric` function.

# %%
# train a dt model with default params
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_42a86_row10_col0, #T_42a86_row10_col1, #T_42a86_row10_col2, #T_42a86_row10_col3, #T_42a86_row10_col4, #T_42a86_row10_col5, #T_42a86_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_42a86" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42a86_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_42a86_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_42a86_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_42a86_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_42a86_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_42a86_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_42a86_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42a86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42a86_row0_col0" class="data row0 col0" >0.8182</td>
#       <td id="T_42a86_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_42a86_row0_col2" class="data row0 col2" >0.8182</td>
#       <td id="T_42a86_row0_col3" class="data row0 col3" >0.8788</td>
#       <td id="T_42a86_row0_col4" class="data row0 col4" >0.8061</td>
#       <td id="T_42a86_row0_col5" class="data row0 col5" >0.7250</td>
#       <td id="T_42a86_row0_col6" class="data row0 col6" >0.7642</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42a86_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_42a86_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_42a86_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_42a86_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_42a86_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_42a86_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_42a86_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42a86_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_42a86_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_42a86_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_42a86_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_42a86_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_42a86_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_42a86_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_42a86_row3_col0" class="data row3 col0" >0.7273</td>
#       <td id="T_42a86_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_42a86_row3_col2" class="data row3 col2" >0.7273</td>
#       <td id="T_42a86_row3_col3" class="data row3 col3" >0.8442</td>
#       <td id="T_42a86_row3_col4" class="data row3 col4" >0.6826</td>
#       <td id="T_42a86_row3_col5" class="data row3 col5" >0.5875</td>
#       <td id="T_42a86_row3_col6" class="data row3 col6" >0.6674</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_42a86_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_42a86_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_42a86_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_42a86_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_42a86_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_42a86_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_42a86_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_42a86_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_42a86_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_42a86_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_42a86_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_42a86_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_42a86_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_42a86_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_42a86_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_42a86_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_42a86_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_42a86_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_42a86_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_42a86_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_42a86_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_42a86_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_42a86_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_42a86_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_42a86_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_42a86_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_42a86_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_42a86_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_42a86_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_42a86_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_42a86_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_42a86_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_42a86_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_42a86_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_42a86_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_42a86_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_42a86_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_42a86_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_42a86_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_42a86_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_42a86_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_42a86_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_42a86_row10_col0" class="data row10 col0" >0.9264</td>
#       <td id="T_42a86_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_42a86_row10_col2" class="data row10 col2" >0.9264</td>
#       <td id="T_42a86_row10_col3" class="data row10 col3" >0.9502</td>
#       <td id="T_42a86_row10_col4" class="data row10 col4" >0.9201</td>
#       <td id="T_42a86_row10_col5" class="data row10 col5" >0.8886</td>
#       <td id="T_42a86_row10_col6" class="data row10 col6" >0.9040</td>
#     </tr>
#     <tr>
#       <th id="T_42a86_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_42a86_row11_col0" class="data row11 col0" >0.0893</td>
#       <td id="T_42a86_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_42a86_row11_col2" class="data row11 col2" >0.0893</td>
#       <td id="T_42a86_row11_col3" class="data row11 col3" >0.0552</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# tune hyperparameters of dt
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_85464_row10_col0, #T_85464_row10_col1, #T_85464_row10_col2, #T_85464_row10_col3, #T_85464_row10_col4, #T_85464_row10_col5, #T_85464_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_85464" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85464_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_85464_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_85464_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_85464_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_85464_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_85464_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_85464_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85464_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85464_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_85464_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_85464_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_85464_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_85464_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_85464_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_85464_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85464_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_85464_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_85464_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_85464_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_85464_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_85464_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_85464_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85464_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_85464_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_85464_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_85464_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_85464_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_85464_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_85464_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85464_row3_col0" class="data row3 col0" >0.7273</td>
#       <td id="T_85464_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_85464_row3_col2" class="data row3 col2" >0.7273</td>
#       <td id="T_85464_row3_col3" class="data row3 col3" >0.8442</td>
#       <td id="T_85464_row3_col4" class="data row3 col4" >0.6826</td>
#       <td id="T_85464_row3_col5" class="data row3 col5" >0.5875</td>
#       <td id="T_85464_row3_col6" class="data row3 col6" >0.6674</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85464_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_85464_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_85464_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_85464_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_85464_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_85464_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_85464_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85464_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_85464_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_85464_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_85464_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_85464_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_85464_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_85464_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_85464_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_85464_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_85464_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_85464_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_85464_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_85464_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_85464_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_85464_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_85464_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_85464_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_85464_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_85464_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_85464_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_85464_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_85464_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_85464_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_85464_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_85464_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_85464_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_85464_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_85464_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_85464_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_85464_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_85464_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_85464_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_85464_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_85464_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_85464_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_85464_row10_col0" class="data row10 col0" >0.9445</td>
#       <td id="T_85464_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_85464_row10_col2" class="data row10 col2" >0.9445</td>
#       <td id="T_85464_row10_col3" class="data row10 col3" >0.9624</td>
#       <td id="T_85464_row10_col4" class="data row10 col4" >0.9395</td>
#       <td id="T_85464_row10_col5" class="data row10 col5" >0.9161</td>
#       <td id="T_85464_row10_col6" class="data row10 col6" >0.9276</td>
#     </tr>
#     <tr>
#       <th id="T_85464_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_85464_row11_col0" class="data row11 col0" >0.0838</td>
#       <td id="T_85464_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_85464_row11_col2" class="data row11 col2" >0.0838</td>
#       <td id="T_85464_row11_col3" class="data row11 col3" >0.0513</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# Metric to optimize can be defined in `optimize` parameter (default = 'Accuracy'). Also, a custom tuned grid can be passed with `custom_grid` parameter.

# %%
dt
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %%
# define tuning grid
dt_grid = {'max_depth' : [None, 2, 4, 6, 8, 10, 12]}

# tune model with custom grid and metric = F1
tuned_dt = tune_model(dt, custom_grid = dt_grid, optimize = 'F1')
# Out:
# <style type="text/css">
# #T_586db_row10_col0, #T_586db_row10_col1, #T_586db_row10_col2, #T_586db_row10_col3, #T_586db_row10_col4, #T_586db_row10_col5, #T_586db_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_586db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_586db_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_586db_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_586db_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_586db_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_586db_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_586db_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_586db_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_586db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_586db_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_586db_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_586db_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_586db_row0_col3" class="data row0 col3" >0.9273</td>
#       <td id="T_586db_row0_col4" class="data row0 col4" >0.9076</td>
#       <td id="T_586db_row0_col5" class="data row0 col5" >0.8625</td>
#       <td id="T_586db_row0_col6" class="data row0 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_586db_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_586db_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_586db_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_586db_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_586db_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_586db_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_586db_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_586db_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_586db_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_586db_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_586db_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_586db_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_586db_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_586db_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_586db_row3_col0" class="data row3 col0" >0.7273</td>
#       <td id="T_586db_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_586db_row3_col2" class="data row3 col2" >0.7273</td>
#       <td id="T_586db_row3_col3" class="data row3 col3" >0.8442</td>
#       <td id="T_586db_row3_col4" class="data row3 col4" >0.6826</td>
#       <td id="T_586db_row3_col5" class="data row3 col5" >0.5875</td>
#       <td id="T_586db_row3_col6" class="data row3 col6" >0.6674</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_586db_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_586db_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_586db_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_586db_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_586db_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_586db_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_586db_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_586db_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_586db_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_586db_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_586db_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_586db_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_586db_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_586db_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_586db_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_586db_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_586db_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_586db_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_586db_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_586db_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_586db_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_586db_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_586db_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_586db_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_586db_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_586db_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_586db_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_586db_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_586db_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_586db_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_586db_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_586db_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_586db_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_586db_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_586db_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_586db_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_586db_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_586db_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_586db_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_586db_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_586db_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_586db_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_586db_row10_col0" class="data row10 col0" >0.9445</td>
#       <td id="T_586db_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_586db_row10_col2" class="data row10 col2" >0.9445</td>
#       <td id="T_586db_row10_col3" class="data row10 col3" >0.9624</td>
#       <td id="T_586db_row10_col4" class="data row10 col4" >0.9395</td>
#       <td id="T_586db_row10_col5" class="data row10 col5" >0.9161</td>
#       <td id="T_586db_row10_col6" class="data row10 col6" >0.9276</td>
#     </tr>
#     <tr>
#       <th id="T_586db_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_586db_row11_col0" class="data row11 col0" >0.0838</td>
#       <td id="T_586db_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_586db_row11_col2" class="data row11 col2" >0.0838</td>
#       <td id="T_586db_row11_col3" class="data row11 col3" >0.0513</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 7 candidates, totalling 70 fits

# %%
# to access the tuner object you can set return_tuner = True
tuned_dt, tuner = tune_model(dt, return_tuner=True)
# Out:
# <style type="text/css">
# #T_77646_row10_col0, #T_77646_row10_col1, #T_77646_row10_col2, #T_77646_row10_col3, #T_77646_row10_col4, #T_77646_row10_col5, #T_77646_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_77646" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77646_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_77646_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_77646_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_77646_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_77646_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_77646_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_77646_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77646_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77646_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_77646_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_77646_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_77646_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_77646_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_77646_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_77646_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77646_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_77646_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_77646_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_77646_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_77646_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_77646_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_77646_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77646_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_77646_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_77646_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_77646_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_77646_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_77646_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_77646_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77646_row3_col0" class="data row3 col0" >0.7273</td>
#       <td id="T_77646_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_77646_row3_col2" class="data row3 col2" >0.7273</td>
#       <td id="T_77646_row3_col3" class="data row3 col3" >0.8442</td>
#       <td id="T_77646_row3_col4" class="data row3 col4" >0.6826</td>
#       <td id="T_77646_row3_col5" class="data row3 col5" >0.5875</td>
#       <td id="T_77646_row3_col6" class="data row3 col6" >0.6674</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77646_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_77646_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_77646_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_77646_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_77646_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_77646_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_77646_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_77646_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_77646_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_77646_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_77646_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_77646_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_77646_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_77646_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_77646_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_77646_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_77646_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_77646_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_77646_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_77646_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_77646_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_77646_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_77646_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_77646_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_77646_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_77646_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_77646_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_77646_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_77646_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_77646_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_77646_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_77646_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_77646_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_77646_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_77646_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_77646_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_77646_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_77646_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_77646_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_77646_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_77646_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_77646_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_77646_row10_col0" class="data row10 col0" >0.9445</td>
#       <td id="T_77646_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_77646_row10_col2" class="data row10 col2" >0.9445</td>
#       <td id="T_77646_row10_col3" class="data row10 col3" >0.9624</td>
#       <td id="T_77646_row10_col4" class="data row10 col4" >0.9395</td>
#       <td id="T_77646_row10_col5" class="data row10 col5" >0.9161</td>
#       <td id="T_77646_row10_col6" class="data row10 col6" >0.9276</td>
#     </tr>
#     <tr>
#       <th id="T_77646_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_77646_row11_col0" class="data row11 col0" >0.0838</td>
#       <td id="T_77646_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_77646_row11_col2" class="data row11 col2" >0.0838</td>
#       <td id="T_77646_row11_col3" class="data row11 col3" >0.0513</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# model object
tuned_dt
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.2, min_samples_leaf=5,
#                        min_samples_split=5, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %%
# help(tune_model)

# %% [markdown]
# ## ✅ Ensemble Model

# %% [markdown]
# This function ensembles a given estimator. The output of this function is a scoring grid with CV scores by fold. Metrics evaluated during CV can be accessed using the `get_metrics` function. Custom metrics can be added or removed using `add_metric` and `remove_metric` function.

# %%
# ensemble with bagging
ensemble_model(dt, method = 'Bagging')
# Out:
# <style type="text/css">
# #T_4c70f_row10_col0, #T_4c70f_row10_col1, #T_4c70f_row10_col2, #T_4c70f_row10_col3, #T_4c70f_row10_col4, #T_4c70f_row10_col5, #T_4c70f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4c70f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c70f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4c70f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4c70f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4c70f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4c70f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4c70f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4c70f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c70f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c70f_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_4c70f_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_4c70f_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_4c70f_row0_col3" class="data row0 col3" >0.9273</td>
#       <td id="T_4c70f_row0_col4" class="data row0 col4" >0.9076</td>
#       <td id="T_4c70f_row0_col5" class="data row0 col5" >0.8625</td>
#       <td id="T_4c70f_row0_col6" class="data row0 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c70f_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_4c70f_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_4c70f_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_4c70f_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_4c70f_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_4c70f_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_4c70f_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c70f_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_4c70f_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_4c70f_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_4c70f_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_4c70f_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_4c70f_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_4c70f_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c70f_row3_col0" class="data row3 col0" >0.7273</td>
#       <td id="T_4c70f_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_4c70f_row3_col2" class="data row3 col2" >0.7273</td>
#       <td id="T_4c70f_row3_col3" class="data row3 col3" >0.8442</td>
#       <td id="T_4c70f_row3_col4" class="data row3 col4" >0.6826</td>
#       <td id="T_4c70f_row3_col5" class="data row3 col5" >0.5875</td>
#       <td id="T_4c70f_row3_col6" class="data row3 col6" >0.6674</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c70f_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_4c70f_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_4c70f_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_4c70f_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_4c70f_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_4c70f_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_4c70f_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c70f_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_4c70f_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_4c70f_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_4c70f_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_4c70f_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_4c70f_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_4c70f_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c70f_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_4c70f_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_4c70f_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_4c70f_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_4c70f_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_4c70f_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_4c70f_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c70f_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_4c70f_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_4c70f_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_4c70f_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_4c70f_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_4c70f_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_4c70f_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c70f_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_4c70f_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_4c70f_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_4c70f_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_4c70f_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_4c70f_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_4c70f_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4c70f_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_4c70f_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_4c70f_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_4c70f_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_4c70f_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_4c70f_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_4c70f_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4c70f_row10_col0" class="data row10 col0" >0.9355</td>
#       <td id="T_4c70f_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_4c70f_row10_col2" class="data row10 col2" >0.9355</td>
#       <td id="T_4c70f_row10_col3" class="data row10 col3" >0.9551</td>
#       <td id="T_4c70f_row10_col4" class="data row10 col4" >0.9303</td>
#       <td id="T_4c70f_row10_col5" class="data row10 col5" >0.9023</td>
#       <td id="T_4c70f_row10_col6" class="data row10 col6" >0.9149</td>
#     </tr>
#     <tr>
#       <th id="T_4c70f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4c70f_row11_col0" class="data row11 col0" >0.0822</td>
#       <td id="T_4c70f_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_4c70f_row11_col2" class="data row11 col2" >0.0822</td>
#       <td id="T_4c70f_row11_col3" class="data row11 col3" >0.0506</td>
#       <td id="
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# BaggingClassifier(bootstrap=True, bootstrap_features=False,
#                   estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                    class_weight=None,
#                                                    criterion='gini',
#                                                    max_depth=None,
#                                                    max_features=None,
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    monotonic_cst=None,
#                                                    random_state=123,
#                                                    splitter='best'),
#                   max_features=1.0, max_samples=1.0, n_estimators=10,
#                   n_jobs=None, oob_score=False, random_state=123, verbose=0,
#                   warm_start=False)

# %%
# ensemble with boosting
ensemble_model(dt, method = 'Boosting')
# Out:
# <style type="text/css">
# #T_e9650_row10_col0, #T_e9650_row10_col1, #T_e9650_row10_col2, #T_e9650_row10_col3, #T_e9650_row10_col4, #T_e9650_row10_col5, #T_e9650_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e9650" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9650_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e9650_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e9650_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e9650_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e9650_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e9650_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e9650_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9650_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9650_row0_col0" class="data row0 col0" >0.9091</td>
#       <td id="T_e9650_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_e9650_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_e9650_row0_col3" class="data row0 col3" >0.9273</td>
#       <td id="T_e9650_row0_col4" class="data row0 col4" >0.9076</td>
#       <td id="T_e9650_row0_col5" class="data row0 col5" >0.8625</td>
#       <td id="T_e9650_row0_col6" class="data row0 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9650_row1_col0" class="data row1 col0" >0.9091</td>
#       <td id="T_e9650_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_e9650_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_e9650_row1_col3" class="data row1 col3" >0.9273</td>
#       <td id="T_e9650_row1_col4" class="data row1 col4" >0.9076</td>
#       <td id="T_e9650_row1_col5" class="data row1 col5" >0.8625</td>
#       <td id="T_e9650_row1_col6" class="data row1 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9650_row2_col0" class="data row2 col0" >0.9091</td>
#       <td id="T_e9650_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_e9650_row2_col2" class="data row2 col2" >0.9091</td>
#       <td id="T_e9650_row2_col3" class="data row2 col3" >0.9273</td>
#       <td id="T_e9650_row2_col4" class="data row2 col4" >0.9076</td>
#       <td id="T_e9650_row2_col5" class="data row2 col5" >0.8625</td>
#       <td id="T_e9650_row2_col6" class="data row2 col6" >0.8735</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9650_row3_col0" class="data row3 col0" >0.6364</td>
#       <td id="T_e9650_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_e9650_row3_col2" class="data row3 col2" >0.6364</td>
#       <td id="T_e9650_row3_col3" class="data row3 col3" >0.6364</td>
#       <td id="T_e9650_row3_col4" class="data row3 col4" >0.6121</td>
#       <td id="T_e9650_row3_col5" class="data row3 col5" >0.4500</td>
#       <td id="T_e9650_row3_col6" class="data row3 col6" >0.4743</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e9650_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_e9650_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_e9650_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_e9650_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_e9650_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_e9650_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_e9650_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e9650_row5_col0" class="data row5 col0" >0.9000</td>
#       <td id="T_e9650_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_e9650_row5_col2" class="data row5 col2" >0.9000</td>
#       <td id="T_e9650_row5_col3" class="data row5 col3" >0.9250</td>
#       <td id="T_e9650_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_e9650_row5_col5" class="data row5 col5" >0.8485</td>
#       <td id="T_e9650_row5_col6" class="data row5 col6" >0.8616</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e9650_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_e9650_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_e9650_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_e9650_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_e9650_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_e9650_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_e9650_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e9650_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_e9650_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_e9650_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_e9650_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_e9650_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_e9650_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_e9650_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e9650_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_e9650_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_e9650_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_e9650_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_e9650_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_e9650_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_e9650_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e9650_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_e9650_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_e9650_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_e9650_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_e9650_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_e9650_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_e9650_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e9650_row10_col0" class="data row10 col0" >0.9264</td>
#       <td id="T_e9650_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_e9650_row10_col2" class="data row10 col2" >0.9264</td>
#       <td id="T_e9650_row10_col3" class="data row10 col3" >0.9343</td>
#       <td id="T_e9650_row10_col4" class="data row10 col4" >0.9232</td>
#       <td id="T_e9650_row10_col5" class="data row10 col5" >0.8886</td>
#       <td id="T_e9650_row10_col6" class="data row10 col6" >0.8956</td>
#     </tr>
#     <tr>
#       <th id="T_e9650_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e9650_row11_col0" class="data row11 col0" >0.1062</td>
#       <td id="T_e9650_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_e9650_row11_col2" class="data row11 col2" >0.1062</td>
#       <td id="T_e9650_row11_col3" class="data row11 col3" >0.1052</td>
#       <td id="
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# AdaBoostClassifier(algorithm='SAMME.R',
#                    estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     monotonic_cst=None,
#                                                     random_state=123,
#                                                     splitter='best'),
#                    learning_rate=1.0, n_estimators=10, random_state=123)

# %% [markdown]
# Some other parameters that you might find very useful in `ensemble_model` are:
#
# - choose_better
# - n_estimators
# - groups
# - fit_kwargs
# - probability_threshold
# - return_train_score
#
# You can check the docstring of the function for more info.

# %%
# help(ensemble_model)
